# %% [markdown]
# ### 데이터 : 서울시 구별 CCTV 대수 + 서울시 구별 인구수(전체,한국인,외국인,65세이상고령자)

# %% [markdown]
# ### 목적 : 데이터 분석

# %%
# 한글폰트 설치
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# ## 폰트 설치후 반드시 재시작!!!

# %%
# matplotlib 나눔바른고딕체로 폰트 변경하기
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
# 데이터 파일을 가져오기 위해 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# CCTV csv파일 가져오기
csvPath='/content/drive/MyDrive/Colab Notebooks/Data Science/4_데이터분석예제/data/01. CCTV_result.csv'
xlsxPath='/content/drive/MyDrive/Colab Notebooks/Data Science/4_데이터분석예제/data/01. population_in_Seoul.xls'

import pandas as pd
import numpy as np

cctv_seoul=pd.read_csv(csvPath) #,encoding='utf-8')

# info(),describe(),head(),tail()
cctv_seoul.head()
# Out:
#     구별    소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 0  강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 1  강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 2  강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 3  강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 4  관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#        고령자비율    CCTV비율           오차
# 0  11.072217  0.487292  1388.055355
# 1  12.051638  0.170552   465.422892
# 2  16.600342  0.226535   329.342026
# 3  12.015794  0.146413   551.503155
# 4  12.955291  0.284673   162.948104

# %%
cctv_seoul.tail()
# Out:
#      구별    소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 20  용산구  1624   53.216374  244203.0  229456.0  14747.0  36231.0  6.038828
# 21  은평구  1873   85.237258  494388.0  489943.0   4445.0  72334.0  0.899091
# 22  종로구  1002  248.922414  162820.0  153589.0   9231.0  25425.0  5.669451
# 23   중구   671  147.699758  133240.0  124312.0   8928.0  20764.0  6.700690
# 24  중랑구   660   79.960707  414503.0  409882.0   4621.0  56774.0  1.114829
#
#         고령자비율    CCTV비율          오차
# 20  14.836427  0.665020  659.231690
# 21  14.631019  0.378852  580.698457
# 22  15.615404  0.615404  143.775396
# 23  15.583909  0.503603  148.499528
# 24  13.696885  0.159227  527.718965

# %%
cctv_seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구별      25 non-null     object
#  1   소계      25 non-null     int64
#  2   최근증가율   25 non-null     float64
#  3   인구수     25 non-null     float64
#  4   한국인     25 non-null     float64
#  5   외국인     25 non-null     float64
#  6   고령자     25 non-null     float64
#  7   외국인비율   25 non-null     float64
#  8   고령자비율   25 non-null     float64
#  9   CCTV비율  25 non-null     float64
#  10  오차      25 non-null     float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 2.3+ KB

# %%
# cctv_seoul의 수치형 데이터 int64, float64인 컬럼 데이터의 통계치를 보여준다.
cctv_seoul.describe()
# Out:
#                 소계       최근증가율           인구수            한국인           외국인  \
# count    25.000000   25.000000      25.00000      25.000000     25.000000
# mean   1179.080000  119.030748  407904.16000  397078.720000  10825.440000
# std     556.728983   61.350043  130273.67526  131802.414218   8301.513236
# min     485.000000   34.671731  133240.00000  124312.000000   2017.000000
# 25%     748.000000   64.973730  330192.00000  326686.000000   4445.000000
# 50%    1015.000000  104.347826  412520.00000  400456.000000   8928.000000
# 75%    1496.000000  150.619195  479978.00000  475949.000000  14747.000000
# max    2780.000000  248.922414  667483.00000  660584.000000  34913.000000
#
#                 고령자      외국인비율      고령자비율     CCTV비율           오차
# count     25.000000  25.000000  25.000000  25.000000    25.000000
# mean   52858.320000   3.105648  13.284569   0.312767   411.679486
# std    14173.072031   2.489046   1.588524   0.150404   322.983467
# min    20764.000000   0.578524  10.862599   0.092587     9.464016
# 25%    48161.000000   0.958451  12.051638   0.189970   148.499528
# 50%    54173.000000   2.526635  12.955291   0.294043   329.592918
# 75%    63167.000000   4.172440  14.661322   0.397911   581.180999
# max    72548.000000   8.663598  16.600342   0.665020  1388.055355

# %%
# 컬럼명 '기관명' -> '구별'
cctv_seoul.rename(columns={'기관명':'구별'},inplace=True)
cctv_seoul.head()
# Out:
#     구별    소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 0  강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 1  강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 2  강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 3  강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 4  관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#        고령자비율    CCTV비율           오차
# 0  11.072217  0.487292  1388.055355
# 1  12.051638  0.170552   465.422892
# 2  16.600342  0.226535   329.342026
# 3  12.015794  0.146413   551.503155
# 4  12.955291  0.284673   162.948104

# %%
cctv_seoul['최근증가율']=(cctv_seoul['2016년']+cctv_seoul['2015년']+cctv_seoul['2014년'])/cctv_seoul['2013년도 이전']*100
cctv_seoul.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2016년'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-54f2271caae3> in <cell line: 1>()
# ----> 1 cctv_seoul['최근증가율']=(cctv_seoul['2016년']+cctv_seoul['2015년']+cctv_seoul['2014년'])/cctv_seoul['2013년도 이전']*100
#       2 cctv_seoul.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: '2016년'

# %%
# 데이터에 질문을 던지자!
# 가장 CCTV대수가 많은 구는 어디? 적은 구는 어디?
# 소계를 기준으로 가장 많은 구 5개, 적은 구 5개 -> 정렬
cctv_seoul.sort_values(by='소계',ascending=False).head()

# %%
cctv_seoul.sort_values(by='소계',ascending=True).head()

# %%
# 질문 : 최근 증가율 가장 높은 5구, 가장 적은 5구
cctv_seoul.sort_values(by='최근증가율',ascending=False).head()

# %%
cctv_seoul.sort_values(by='최근증가율',ascending=True).head()

# %%
# cctv_seoul에서 '2013년도 이전', '2014년', '2015년', '2016년' 컬럼을 삭제
cctv_seoul.drop(['2013년도 이전','2014년','2015년','2016년'],axis=1,inplace=True)
cctv_seoul.head()

# %%
cctv_seoul.tail()

# %%
# usecols를 알기 위해서는 먼저 excel파일의 내용을 눈으로 확인한 후에 선택한다.
pop_seoul=pd.read_excel(xlsxPath,header=2,usecols='B,D,G,J,N')
pop_seoul.head()

# %%
pop_seoul.tail()

# %%
pop_seoul.columns

# %%
# 컬럼명 변경하기
pop_seoul.columns = ['구별', '인구', '한국인', '외국인', '고령자']
pop_seoul.head()

# %%
# 불필요한 행[0,26]을 삭제하기
pop_seoul.drop([0,26],inplace=True)
pop_seoul

# %%
# index 번호를 0~24로 변경
pop_seoul.reset_index(drop=True,inplace=True)
pop_seoul

# %%
# cctv_seoul, pop_seoul 데이터프레임 합치기
data_result=pd.merge(pop_seoul,cctv_seoul,on='구별')
data_result.head()

# %%
# 고령자의 비율
data_result['고령자비율']=data_result['고령자']/data_result['인구']*100

# %%
# 외국인의 비율
data_result['외국인비율']=data_result['외국인']/data_result['인구']*100

# %%
data_result.head()

# %%
# 컬럼명 다시 변경
data_result.columns=['구별','인구','한국인','외국인','고령자','CCTV대수','CCTV증가율','고령자비율','외국인비율']
data_result.head()

# %%
# matplotlib으로 그래프를 그리기 위해서는 index를 '구별'로 변경
data_result.set_index('구별',inplace=True)
data_result.head()

# %% [markdown]
# ### matplotlib의 CheetSheet
# https://matplotlib.org/cheatsheets/

# %%
# data_result['소계']를 barh형태로 plot하자
data_result['CCTV대수'].plot(kind='barh',grid=True,figsize=(10,10))

# %%
# matplotlib으로 'CCTV대수'를 기준으로 가장 많은 구부터 출력
# sort_values를 data_result에 저장하고, 다음 줄에서 plot
data_result.sort_values(by='CCTV대수',ascending=False,inplace=True)
data_result['CCTV대수'].plot(kind='barh',grid=True,figsize=(10,10))

# %%
data_result['CCTV대수'].sort_values(ascending=True).plot(kind='bar',grid=True,figsize=(10,10))

# %%
# matplotlib으로 가로축은 '인구', 세로축은 'CCTV대수'인 scatter 그래프를 출력
plt.figure(figsize=(6,6))
# 산점도(x,y,s) s는 점의 크기
plt.scatter(data_result['인구'], data_result['CCTV대수'], s=25)
plt.xlabel('인구')
plt.ylabel('CCTV대수')
plt.grid()
plt.show()

# %%
# x,y 데이터를 받아들여서 1차함수를 생성(직선의 방정식)
fp1 = np.polyfit(data_result['인구'], data_result['CCTV대수'], 1)
f1 = np.poly1d(fp1)
fx = np.linspace(100000, 700000, 100)

plt.figure(figsize=(6,6))
plt.scatter(data_result['인구'], data_result['CCTV대수'], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g')
plt.xlabel('인구')
plt.ylabel('CCTV')
plt.grid()
plt.show()

# %%
data_result['오차'] = np.abs(data_result['CCTV대수'] - f1(data_result['인구']))
df_sort = data_result.sort_values(by='오차', ascending=False)
df_sort.head()

# %%
plt.figure(figsize=(14,10))
plt.scatter(data_result['인구'], data_result['CCTV대수'],
            c=data_result['오차'], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g')

for n in range(25):
    # text를 출력할 x좌표의 시작점, y좌표의 시작점, 찍을 내용
    plt.text(df_sort['인구'][n]+7500, df_sort['CCTV대수'][n]-25,
             df_sort.index[n], fontsize=12)


plt.text(400000-25000, 2800, temp, fontsize=15)

plt.xlabel('인구수')
plt.ylabel('인구당비율')
plt.colorbar()
plt.grid()
plt.show()
