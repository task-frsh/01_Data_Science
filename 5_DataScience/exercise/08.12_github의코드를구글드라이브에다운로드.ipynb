# %%
# 내 구글드라이브에 github소스코드 다운로드하기
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
downloadPath ='/content/drive/MyDrive'

import os

# 작업디렉토리 이동
os.chdir(downloadPath)

# 현재 작업디렉토리를 확인하는 리눅스 명령
# !pwd
# Out:
# /content/drive/MyDrive

# %%
# 내 구글 드라이브 MyDrive밑에 DataScience폴더가 생성됨
# !git clone https://github.com/PinkWink/DataScience.git
# Out:
# Cloning into 'DataScience'...
# remote: Enumerating objects: 399, done.
# remote: Total 399 (delta 0), reused 0 (delta 0), pack-reused 399
# Receiving objects: 100% (399/399), 23.97 MiB | 12.49 MiB/s, done.
# Resolving deltas: 100% (227/227), done.
# Updating files: 100% (94/94), done.
