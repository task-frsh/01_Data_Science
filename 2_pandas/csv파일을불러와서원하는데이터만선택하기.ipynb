# %%
import pandas as pd

filePath = '/content/drive/MyDrive/서울ICT_인공지능중급/code/3_pandas/subway1.csv'
df = pd.read_csv(filePath, encoding='cp949')

# %%
df.head()
# Out:
#   조사일자   호선  역번호   역명  구분 5시30분  ... 22시00분 22시30분 23시00분 23시30분 24시00분 24시30분
# 0   평일  1호선  150  서울역  상선   8.2  ...     19   15.2   10.5    7.8      6    0.9
# 1   평일  1호선  150  서울역  하선  11.8  ...   45.6   37.8   28.8   19.3    7.1    0.4
# 2   평일  1호선  151   시청  상선   7.7  ...     24   18.7   13.7     10    6.9    1.0
# 3   평일  1호선  151   시청  하선   9.5  ...   37.4   36.3     23   18.1      4    1.6
# 4   평일  1호선  152   종각  상선   6.3  ...     34   26.8   18.8   12.5    9.1    1.2
#
# [5 rows x 44 columns]

# %%
df.columns
# Out:
# Index(['조사일자', '호선', '역번호', '역명', '구분', '5시30분', '6시00분', '6시30분', '7시00분',
#        '7시30분', '8시00분', '8시30분', '9시00분', '9시30분', '10시00분', '10시30분',
#        '11시00분', '11시30분', '12시00분', '12시30분', '13시00분', '13시30분', '14시00분',
#        '14시30분', '15시00분', '15시30분', '16시00분', '16시30분', '17시00분', '17시30분',
#        '18시00분', '18시30분', '19시00분', '19시30분', '20시00분', '20시30분', '21시00분',
#        '21시30분', '22시00분', '22시30분', '23시00분', '23시30분', '24시00분', '24시30분'],
#       dtype='object')

# %%
# loc를 사용하여 필요한 열 추출하기
my_df = df.loc[:, ['조사일자','호선', '역명', '구분','8시00분', '8시30분', '9시00분','18시00분', '18시30분', '19시00분']]

# %%
my_df
# Out:
#      조사일자   호선   역명  구분 8시00분 8시30분 9시00분 18시00분 18시30분 19시00분
# 0      평일  1호선  서울역  상선    70  74.5  52.2   40.3   42.7   29.8
# 1      평일  1호선  서울역  하선  34.8  25.2    21  105.6   76.5     51
# 2      평일  1호선   시청  상선  53.7  51.7  47.1   51.1   48.7   36.1
# 3      평일  1호선   시청  하선  34.1  26.4    21   88.8   73.4   48.1
# 4      평일  1호선   종각  상선  34.8  28.7  32.4   65.5   58.2   42.1
# ...   ...  ...  ...  ..   ...   ...   ...    ...    ...    ...
# 1663  일요일  8호선   신흥  하선   5.4     6   8.2    5.6    5.5    4.7
# 1664  일요일  8호선   수진  상선   3.3   4.1   5.6    6.7    9.1      6
# 1665  일요일  8호선   수진  하선   5.5   5.8   7.6      5    3.1      3
# 1666  일요일  8호선   모란  상선   2.1   3.1   3.2    5.9    9.4    6.3
# 1667  일요일  8호선   모란  하선     0     0     0      0      0      0
#
# [1668 rows x 10 columns]

# %%
# loc를 사용하여 필요한 행 추출하기
# boolean indexing을 활용하자
my_df['호선']=='1호선'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1663    False
# 1664    False
# 1665    False
# 1666    False
# 1667    False
# Name: 호선, Length: 1668, dtype: bool

# %%
my_df = my_df[my_df['호선']=='1호선']

# %%
my_df = my_df.reset_index(drop=True)

# %%
my_df
# Out:
#    조사일자   호선    역명  구분 8시00분 8시30분 9시00분 18시00분 18시30분 19시00분
# 0    평일  1호선   서울역  상선    70  74.5  52.2   40.3   42.7   29.8
# 1    평일  1호선   서울역  하선  34.8  25.2    21  105.6   76.5     51
# 2    평일  1호선    시청  상선  53.7  51.7  47.1   51.1   48.7   36.1
# 3    평일  1호선    시청  하선  34.1  26.4    21   88.8   73.4   48.1
# 4    평일  1호선    종각  상선  34.8  28.7  32.4   65.5   58.2   42.1
# 5    평일  1호선    종각  하선  44.2  41.2  26.7   74.7   56.5   38.6
# 6    평일  1호선  종로3가  상선  36.2  34.8  31.1   63.2   67.2   45.6
# 7    평일  1호선  종로3가  하선    59  69.1  37.4   54.2   43.9   29.8
# 8    평일  1호선  종로5가  상선  28.8  23.6  21.3   69.5     68   51.5
# 9    평일  1호선  종로5가  하선  70.8  68.2  37.2     57   39.4   28.1
# 10   평일  1호선   동대문  상선  26.1  23.6  20.5   67.8   72.5   50.4
# 11   평일  1호선   동대문  하선  77.4    77  40.5   41.8   31.7   22.3
# 12   평일  1호선   신설동  상선  17.6  17.6  18.5   58.2   64.1   45.4
# 13   평일  1호선   신설동  하선  72.8  66.8    40     39   25.9   19.3
# ...

# %% [markdown]
# ### 시간대별로 혼잡도가 가장 높은 역명을 출력하기

# %%
import pandas as pd

filePath = '/content/drive/MyDrive/서울ICT_인공지능중급/code/3_pandas/subway1.csv'
df = pd.read_csv(filePath, encoding='cp949')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1668 entries, 0 to 1667
# Data columns (total 44 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   조사일자    1668 non-null   object
#  1   호선      1668 non-null   object
#  2   역번호     1668 non-null   int64
#  3   역명      1668 non-null   object
#  4   구분      1668 non-null   object
#  5   5시30분   1668 non-null   object
#  6   6시00분   1668 non-null   object
#  7   6시30분   1668 non-null   object
#  8   7시00분   1668 non-null   object
#  9   7시30분   1668 non-null   object
#  10  8시00분   1668 non-null   object
#  11  8시30분   1668 non-null   object
#  12  9시00분   1668 non-null   object
#  13  9시30분   1668 non-null   object
#  14  10시00분  1668 non-null   object
#  15  10시30분  1668 non-null   object
#  16  11시00분  1668 non-null   object
#  17  11시30분  1668 non-null   object
#  18  12시00분  1668 non-null   object
#  19  12시30분  1668 non-null   object
#  20  13시00분  1668 non-null   object
# ...
